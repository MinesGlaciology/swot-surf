# %%
# Zachary Katz
# zachary_katz@mines.edu
# 07 May 2025
# Gigi Albers

"""
Example notebook to stream and plot SWOT data

Revision History
v0.1 - 7 May 2025
    SWOT track over Bach ice shelf
v0.2 - 22 May 2025
    Removed Mosaic of Antarctica backdrop
"""

# Imports
# %load_ext autoreload
# %autoreload 2

import util.plotting_helpers as plothelp
import matplotlib.pyplot as plt
import earthaccess
import xarray as xr
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from pyproj import Transformer


# Setup earthaccess.
# Follows protocol in https://book.cryointhecloud.com/how_tos/background/earthdata.html
auth = earthaccess.login(strategy="netrc")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Stream SWOT high resolution 100m raster
# Data info at https://podaac.jpl.nasa.gov/dataset/SWOT_L2_HR_Raster_100m_2.0
# See documentation tab for the product description document, which explain variables and file structure
# See data access -> search granules for map to search names
# Currently hardcoded one granule name, but can also search with spatial and temporal bounding boxes


# To view a new granule, paste the corresponding granule name and date into the correct rows. 
# Find new longitude and latitude of new granule and paste into bbox as [longitude_min, longitude_max, latitude_min, latitude_max] formula

# %%
def plot_raster(size, ds, bbox, title, vmin=0, vmax=100, to_plot="wse"):
    """
    Parameters:
    size - figure size in cm [width, height]
    ds - xarray dataset
    bbox - bounding box [min_lon, min_lat, max_lon, max_lat]
    title - plot title
    vmin - minimum value for color scale (default 0)
    vmax - maximum value for color scale (default 100)
    to_plot - variable to plot (default "wse")
    """

results = earthaccess.search_data(
    short_name=input(""), #SWOT_L2_HR_Raster_D
    temporal=input("YYYY-DD-MM,YYYY-DD-MM"), #"2025-06-02", "2025-06-02"), # "2025-05-05", "2025-05-05"
    granule_name=input("") #"SWOT_L2_HR_Raster_250m_UTM54U_N_x_x_x_033_420_030F_20250602T210220_20250602T210241_PID0_01.nc" # "SWOT_L2_HR_Raster_250m_UTM32N_N_x_x_x_032_223_081F_20250505T233927_20250505T233934_PID0_02.nc"
)

swot_ds = xr.open_dataset(earthaccess.open(results)[0], engine="h5netcdf")


print(f"Number of granules found: {len(results)}")
if len(results) == 0:
    print("No granules found! Check your search parameters.")
else:
    print("Granules found. Proceeding to open...")
    
    # Converting cm to inches
    fig = plt.figure(figsize=(size[0]/2.54, size[1]/2.54))  
    ax = fig.add_subplot(111, projection=ccrs.PlateCarree())
    
    # Set focus to West Africa
    ax.gridlines(draw_labels=True)
    
    # Add map features
    ax.add_feature(cfeature.LAND, facecolor='lightgray')
    ax.add_feature(cfeature.OCEAN, facecolor='lightblue')
    ax.coastlines(resolution='10m', linewidth=1)

    # Get data
    wse = ds[to_plot]
    if to_plot == "wse":
        wse = wse + ds["height_cor_xover"]
    
    # Convert UTM to lat/lon
    utm_zone = ds.utm_zone_num
    utm_crs = ccrs.UTM(zone=utm_zone, southern_hemisphere=False)
    transformer = Transformer.from_crs(utm_crs, ccrs.PlateCarree(), always_xy=True)
    x_utm, y_utm = wse["x"].values, wse["y"].values
    X_utm, Y_utm = np.meshgrid(x_utm, y_utm)
    X_lon, Y_lat = transformer.transform(X_utm, Y_utm)
    print("UTM zone:", ds.utm_zone_num)
    
    # Plot SWOT data
    mesh = ax.pcolormesh(
        X_lon,
        Y_lat,
        wse.values,
        transform=ccrs.PlateCarree(),
        cmap="viridis",
        vmin=vmin,
        vmax=vmax,
    )

    # Add colorbar
    cbar = fig.colorbar(mesh, ax=ax, shrink=0.7, location="right", pad=0.15)
    cbar.set_label("Water Surface Elevation [m]")
    
    ax.set_title(title, fontsize=16)
    return fig, ax

def plot_small_inset(fig, position, bbox):
    ax_inset = fig.add_axes(position, projection=ccrs.PlateCarree())
    
    # Find a new wide set of longitudes and latitudes that clearly indicate where you are
    ax_inset.set_extent([120, 150, 30, 60], crs=ccrs.PlateCarree()) #[longitude_min, longitude_max, latitude_min, latitude_max], [-20, 20, 0, 30]
    
    # Add features
    ax_inset.add_feature(cfeature.LAND, facecolor='lightgray')
    ax_inset.add_feature(cfeature.OCEAN, facecolor='lightblue')
    ax_inset.coastlines(resolution='50m', linewidth=0.5)
    
    # Add red rectangle showing specific area 
    rect = plt.Rectangle(
        (bbox[1], bbox[0]), 
        bbox[2]-bbox[0], 
        bbox[3]-bbox[1],
        fill=False, color='red', linewidth=1,
        transform=ccrs.PlateCarree()
    )
    ax_inset.add_patch(rect)
    
    ax_inset.set_title("Location", fontsize=8)
    return ax_inset
# Out:
#  SWOT_L2_HR_Raster_D

# %%
fig, ax = plot_raster(
    size=[15, 15],
    ds=swot_ds,
    bbox=bbox,
    title="SWOT Data - East Russian Coast", # Change name as needed
    vmin=0,
    vmax=10,
    to_plot="wse"
)

# Add inset map
inset = plot_small_inset(
    fig=fig,
    position=[0.95, 0.5, 0.25, 0.25],  # [left, bottom, width, height]
    bbox= [52.96899,141.57496,54.41763,144.0333] #[3.35058, 6.26802, 4.6684, 7.57602]
)

plt.show()
# Out:
# UTM zone: 54

# %%
swot_ds
# Out:
# <xarray.Dataset> Size: 85MB
# Dimensions:                  (x: 659, y: 658)
# Coordinates:
#   * x                        (x) float64 5kB 5.37e+05 5.372e+05 ... 7.015e+05
#   * y                        (y) float64 5kB 5.87e+06 5.87e+06 ... 6.034e+06
# Data variables: (12/39)
#     crs                      object 8B ...
#     longitude                (y, x) float64 3MB ...
#     latitude                 (y, x) float64 3MB ...
#     wse                      (y, x) float32 2MB ...
#     wse_qual                 (y, x) float32 2MB ...
#     wse_qual_bitwise         (y, x) float64 3MB ...
#     ...                       ...
#     load_tide_fes            (y, x) float32 2MB ...
#     load_tide_got            (y, x) float32 2MB ...
#     pole_tide                (y, x) float32 2MB ...
#     model_dry_tropo_cor      (y, x) float32 2MB ...
#     model_wet_tropo_cor      (y, x) float32 2MB ...
#     iono_cor_gim_ka          (y, x) float32 2MB ...
# Attributes: (12/49)
# ...
